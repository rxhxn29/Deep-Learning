# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
df = pd.read_csv('ccp.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.drop('customerID', axis=1, inplace=True)

df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB
# C:\Users\Rohan\AppData\Local\Temp\ipykernel_8476\2025879034.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)

# %%
# #   Column            Non-Null Count  Dtype  
# ---  ------            --------------  -----  
#  0   customerID        7043 non-null   object 
#  1   gender            7043 non-null   object 
#  2   SeniorCitizen     7043 non-null   int64  
#  3   Partner           7043 non-null   object 
#  4   Dependents        7043 non-null   object 
#  5   tenure            7043 non-null   int64  
#  6   PhoneService      7043 non-null   object 
#  7   MultipleLines     7043 non-null   object 
#  8   InternetService   7043 non-null   object 
#  9   OnlineSecurity    7043 non-null   object 
#  10  OnlineBackup      7043 non-null   object 
#  11  DeviceProtection  7043 non-null   object 
#  12  TechSupport       7043 non-null   object 
#  13  StreamingTV       7043 non-null   object 
#  14  StreamingMovies   7043 non-null   object 
#  15  Contract          7043 non-null   object 
#  16  PaperlessBilling  7043 non-null   object 
#  17  PaymentMethod     7043 non-null   object 
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64 
#  20  Churn             7043 non-null   object 


from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
numeric_cols = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',
                'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
                'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

for col in numeric_cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0  Female              0        1  ...           29.85         29.85      0
# 1    Male              0        0  ...           56.95       1889.50      0
# 2    Male              0        0  ...           53.85        108.15      1
# 3    Male              0        0  ...           42.30       1840.75      0
# 4  Female              0        0  ...           70.70        151.65      1
#
# [5 rows x 20 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
num_features = ['tenure', 'MonthlyCharges', 'TotalCharges']
df[num_features] = scaler.fit_transform(df[num_features])
df.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0  Female              0        1  ...       -1.160323     -0.994242      0
# 1    Male              0        0  ...       -0.259629     -0.173244      0
# 2    Male              0        0  ...       -0.362660     -0.959674      1
# 3    Male              0        0  ...       -0.746535     -0.194766      0
# 4  Female              0        0  ...        0.197365     -0.940470      1
#
# [5 rows x 20 columns]

# %%
df['gender'] = le.fit_transform(df['gender'])
df.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0       0              0        1  ...       -1.160323     -0.994242      0
# 1       1              0        0  ...       -0.259629     -0.173244      0
# 2       1              0        0  ...       -0.362660     -0.959674      1
# 3       1              0        0  ...       -0.746535     -0.194766      0
# 4       0              0        0  ...        0.197365     -0.940470      1
#
# [5 rows x 20 columns]

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
x_train, y_train = smote.fit_resample(x_train, y_train)
# Out:
# c:\Users\Rohan\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\Rohan\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Users\Rohan\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Rohan\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Rohan\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^

# %%
y_train.value_counts()
# Out:
# Churn
# 0    4138
# 1    4138
# Name: count, dtype: int64

# %%
model = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(x_train.shape[1],)),
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])  
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# c:\Users\Rohan\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 32)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,313 (5.13 KB)
#  Trainable params: 1,313 (5.13 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7399 - loss: 0.5205 - val_accuracy: 0.7766 - val_loss: 0.5300
# Epoch 2/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7727 - loss: 0.4719 - val_accuracy: 0.7047 - val_loss: 0.6196
# Epoch 3/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7790 - loss: 0.4651 - val_accuracy: 0.7754 - val_loss: 0.5100
# Epoch 4/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7760 - loss: 0.4597 - val_accuracy: 0.7470 - val_loss: 0.5508
# Epoch 5/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7817 - loss: 0.4558 - val_accuracy: 0.7319 - val_loss: 0.5791
# Epoch 6/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7820 - loss: 0.4541 - val_accuracy: 0.7663 - val_loss: 0.5113
# Epoch 7/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7808 - loss: 0.4509 - val_accuracy: 0.8110 - val_loss: 0.4506
# Epoch 8/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7825 - loss: 0.4500 - val_accuracy: 0.6830 - val_loss: 0.6402
# Epoch 9/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7828 - loss: 0.4458 - val_accuracy: 0.7488 - val_loss: 0.5381
# Epoch 10/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7870 - loss: 0.4452 - val_accuracy: 0.7585 - val_loss: 0.5146
# Epoch 11/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7872 - loss: 0.4412 - val_accuracy: 0.7639 - val_loss: 0.5016
# Epoch 12/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7864 - loss: 0.4416 - val_accuracy: 0.7530 - val_loss: 0.5213
# Epoch 13/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7908 - loss: 0.4390 - val_accuracy: 0.7772 - val_loss: 0.4928
# Epoch 14/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7911 - loss: 0.4363 - val_accuracy: 0.7766 - val_loss: 0.4858
# Epoch 15/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7929 - loss: 0.4373 - val_accuracy: 0.7657 - val_loss: 0.5127
# Epoch 16/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7911 - loss: 0.4362 - val_accuracy: 0.7524 - val_loss: 0.5285
# Epoch 17/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7932 - loss: 0.4322 - val_accuracy: 0.8478 - val_loss: 0.3878
# Epoch 18/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7964 - loss: 0.4320 - val_accuracy: 0.7572 - val_loss: 0.5250
# Epoch 19/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7958 - loss: 0.4296 - val_accuracy: 0.7264 - val_loss: 0.5788
# Epoch 20/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7977 - loss: 0.4288 - val_accuracy: 0.7826 - val_loss: 0.4875
# Epoch 21/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7956 - loss: 0.4248 - val_accuracy: 0.8134 - val_loss: 0.4491
# Epoch 22/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7982 - loss: 0.4231 - val_accuracy: 0.7464 - val_loss: 0.5402
# Epoch 23/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7983 - loss: 0.4239 - val_accuracy: 0.7627 - val_loss: 0.5081
# Epoch 24/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8000 - loss: 0.4203 - val_accuracy: 0.7585 - val_loss: 0.5001
# Epoch 25/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7997 - loss: 0.4189 - val_accuracy: 0.7458 - val_loss: 0.5570
# Epoch 26/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8003 - loss: 0.4202 - val_accuracy: 0.7585 - val_loss: 0.5117
# Epoch 27/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7991 - loss: 0.4164 - val_accuracy: 0.7886 - val_loss: 0.4843
# Epoch 28/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8054 - loss: 0.4152 - val_accuracy: 0.7645 - val_loss: 0.5135
# Epoch 29/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8054 - loss: 0.4135 - val_accuracy: 0.7717 - val_loss: 0.5020
# Epoch 30/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8068 - loss: 0.4109 - val_accuracy: 0.8200 - val_loss: 0.4263
# Epoch 31/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8076 - loss: 0.4093 - val_accuracy: 0.7977 - val_loss: 0.4790
# Epoch 32/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8044 - loss: 0.4101 - val_accuracy: 0.8665 - val_loss: 0.3839
# Epoch 33/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.
100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8258 - loss: 0.3761 - val_accuracy: 0.8007 - val_loss: 0.4667
# Epoch 69/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8248 - loss: 0.3753 - val_accuracy: 0.8152 - val_loss: 0.4336
# Epoch 70/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8254 - loss: 0.3768 - val_accuracy: 0.8068 - val_loss: 0.4498
# Epoch 71/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8285 - loss: 0.3715 - val_accuracy: 0.7802 - val_loss: 0.4874
# Epoch 72/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8264 - loss: 0.3741 - val_accuracy: 0.8182 - val_loss: 0.4407
# Epoch 73/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8281 - loss: 0.3723 - val_accuracy: 0.7343 - val_loss: 0.5600
# Epoch 74/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8281 - loss: 0.3746 - val_accuracy: 0.7693 - val_loss: 0.5127
# Epoch 75/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8264 - loss: 0.3720 - val_accuracy: 0.7277 - val_loss: 0.5644
# Epoch 76/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8296 - loss: 0.3689 - val_accuracy: 0.8418 - val_loss: 0.4082
# Epoch 77/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8310 - loss: 0.3701 - val_accuracy: 0.7935 - val_loss: 0.4640
# Epoch 78/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8266 - loss: 0.3696 - val_accuracy: 0.7585 - val_loss: 0.5283
# Epoch 79/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8304 - loss: 0.3701 - val_accuracy: 0.7995 - val_loss: 0.4679
# Epoch 80/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8310 - loss: 0.3684 - val_accuracy: 0.8219 - val_loss: 0.4366
# Epoch 81/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8310 - loss: 0.3704 - val_accuracy: 0.7754 - val_loss: 0.4958
# Epoch 82/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8292 - loss: 0.3676 - val_accuracy: 0.8539 - val_loss: 0.3991
# Epoch 83/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8301 - loss: 0.3640 - val_accuracy: 0.7965 - val_loss: 0.4599
# Epoch 84/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8310 - loss: 0.3648 - val_accuracy: 0.7669 - val_loss: 0.4977
# Epoch 85/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8334 - loss: 0.3664 - val_accuracy: 0.7880 - val_loss: 0.4886
# Epoch 86/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8341 - loss: 0.3641 - val_accuracy: 0.7675 - val_loss: 0.4968
# Epoch 87/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8329 - loss: 0.3632 - val_accuracy: 0.7893 - val_loss: 0.4645
# Epoch 88/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8322 - loss: 0.3615 - val_accuracy: 0.9052 - val_loss: 0.2813
# Epoch 89/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8328 - loss: 0.3617 - val_accuracy: 0.8164 - val_loss: 0.4497
# Epoch 90/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8360 - loss: 0.3602 - val_accuracy: 0.7820 - val_loss: 0.4785
# Epoch 91/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8337 - loss: 0.3599 - val_accuracy: 0.7657 - val_loss: 0.5137
# Epoch 92/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8364 - loss: 0.3602 - val_accuracy: 0.7518 - val_loss: 0.5477
# Epoch 93/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8341 - loss: 0.3615 - val_accuracy: 0.8521 - val_loss: 0.3775
# Epoch 94/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8319 - loss: 0.3605 - val_accuracy: 0.7947 - val_loss: 0.4671
# Epoch 95/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8335 - loss: 0.3586 - val_accuracy: 0.7784 - val_loss: 0.5111
# Epoch 96/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8353 - loss: 0.3579 - val_accuracy: 0.8357 - val_loss: 0.4176
# Epoch 97/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8391 - loss: 0.3562 - val_accuracy: 0.8128 - val_loss: 0.4497
# Epoch 98/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8399 - loss: 0.3556 - val_accuracy: 0.8297 - val_loss: 0.4419
# Epoch 99/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8356 - loss: 0.3579 - val_accuracy: 0.7814 - val_loss: 0.4947
# Epoch 100/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8370 - loss: 0.3555 - val_accuracy: 0.7536 - val_loss: 0.5518

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = (model.predict(x_test) > 0.5).astype("int32")
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      1036
#            1       0.60      0.58      0.59       373
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.72      0.72      1409
# weighted avg       0.78      0.79      0.79      1409

# %%
model.save('customer_churn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
